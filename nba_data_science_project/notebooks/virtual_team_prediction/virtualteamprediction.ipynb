# %% [markdown]
# ## Import necessary libraries

# %%
import warnings
warnings.simplefilter('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

import joblib

# %% [markdown]
# ## Read and Display NBA data

# %%
raptordata = pd.read_csv(r'C:\Users\User\Downloads\nba_data_science_project\data\rawdata\latest_RAPTOR_by_team.csv')
nbadf = pd.read_csv(r"C:\Users\User\Downloads\nba_data_science_project\data\transformed_data\nba_16-23.csv")

# %%
# Display NBA players' game stats/data

raptordata.head()
# Out:
#         player_name  player_id  season season_type team  poss    mp  \
# 0  Precious Achiuwa  achiupr01    2023          RS  TOR  2328  1140
# 1      Steven Adams  adamsst01    2023          RS  MEM  2391  1133
# 2       Bam Adebayo  adebaba01    2023          PO  MIA  1192   598
# 3       Bam Adebayo  adebaba01    2023          RS  MIA  5252  2598
# 4      Ochai Agbaji  agbajoc01    2023          RS  UTA  2604  1209
#
#    raptor_box_offense  raptor_box_defense  raptor_box_total  ...  \
# 0           -2.436260            0.613139         -1.823122  ...
# 1           -0.537262            4.171893          3.634631  ...
# 2           -1.468046            1.692868          0.224823  ...
# 3           -1.856952            2.661994          0.805041  ...
# 4           -1.328228           -2.197352         -3.525581  ...
#
#    raptor_offense  raptor_defense  raptor_total  war_total  war_reg_season  \
# 0       -1.764278       -0.275741     -2.040019   0.409029        0.409029
# 1        0.418716        3.548031      3.966747   3.891812        3.891812
# 2       -1.176961        2.366698      1.189737   1.230109        0.000000
# 3       -1.150384        2.717080      1.566696   5.696162        5.696162
# 4       -1.014981       -1.963656     -2.978636  -0.141332       -0.141332
#
#    war_playoffs  predator_offense  predator_defense  predator_total  \
# 0      0.000000         -1.850761         -0.175280       -2.026041
# 1      0.000000          0.027877          3.566829        3.594706
# 2      1.230109          0.216186          1.569094        1.785280
# 3      0.000000         -0.958213          2.653257        1.695044
# 4      0.000000         -1.157265         -2.504082       -3.661347
#
#    pace_impact
# 0    -0.957109
# 1     0.237911
# 2    -0.761953
# 3    -0.451875
# 4     0.215671
#
# [5 rows x 23 columns]

# %%
# Get the unique categories of the 'season_type' column

raptordata['season_type'].unique()
# Out:
# array(['RS', 'PO'], dtype=object)

# %%
# Create dataframe containing data for only the Regular Season (RS)

rs_raptordata = raptordata.loc[raptordata['season_type'] == 'RS']

# %% [markdown]
# ## Virtual Team

# %%
# Create virtual team of 15 randomly selected players

virtualteamdf = rs_raptordata.sample(n=15)
virtualteamdf
# Out:
#             player_name  player_id  season season_type team  poss    mp  \
# 805     Zion Williamson  willizi01    2023          RS  NOP  2035   956
# 718        Jayson Tatum  tatumja01    2023          RS  BOS  5678  2732
# 47          Will Barton  bartowi01    2023          RS  WAS  1637   782
# 624       Neemias Queta  quetane01    2023          RS  SAC    70    29
# 80   Brandon Boston Jr.  bostobr01    2023          RS  LAC   529   248
# 143      Brandon Clarke  clarkbr01    2023          RS  MEM  2362  1090
# 778       Peyton Watson  watsope01    2023          RS  DEN   383   186
# 277          AJ Griffin  griffaj01    2023          RS  ATL  2997  1401
# 99          Bruce Brown  brownbr01    2023          RS  DEN  4712  2280
# 612        Micah Potter  pottemi01    2023          RS  UTA   117    52
# 690        Kobi Simmons  simmoko01    2023          RS  CHA    60    28
# 695        Marcus Smart  smartma01    2023          RS  BOS  4106  1957
# 765    Lonnie Walker IV  walkelo01    2023          RS  LAL  2811  1297
# 357       Frank Jackson  jacksfr01    2023          RS  UTA     9     5
# 0      Precious Achiuwa  achiupr01    2023          RS  TOR  2328  1140
#
#      raptor_box_offense  raptor_box_defense  raptor_box_total  ...  \
# 805            3.330455           -0.088071          3.242384  ...
# 718            4.080800           -0.523465          3.557335  ...
# 47            -1.197453           -4.870875         -6.068328  ...
# 624           -2.489666           -3.380050         -5.869716  ...
# 80             1.229145           -1.068228          0.160918  ...
# 143           -0.284359            0.302220          0.017860  ...
# 778           -3.283507           -3.426445         -6.709952  ...
# 277            0.091348           -1.074463         -0.983115  ...
# 99            -0.772780            0.666994         -0.105786  ...
# 612            1.647750            2.031994          3.679744  ...
# 690           -3.759593            3.953609          0.194016  ...
# 695           -0.143907            1.338223          1.194316  ...
# 765           -2.000421           -2.017951         -4.018372  ...
# 357          -26.120511            3.394781        -22.725730  ...
# 0             -2.436260            0.613139         -1.823122  ...
#
#      raptor_offense  raptor_defense  raptor_total  war_total  war_reg_season  \
# 805        3.171139        0.410730      3.581869   3.120498        3.120498
# 718        4.433547       -0.730195      3.703352   8.989684        8.989684
# 47        -1.967554       -4.329319     -6.296874  -1.413247       -1.413247
# 624       -6.363588       -3.350069     -9.713657  -0.104016       -0.104016
# 80         0.494293       -1.557353     -1.063059   0.213268        0.213268
# 143       -0.771216        0.573387     -0.197829   1.421004        1.421004
# 778       -4.033737       -3.186268     -7.220006  -0.423544       -0.423544
# 277        0.367446       -0.591416     -0.223970   1.799740        1.799740
# 99        -1.748989        0.478078     -1.270911   1.704732        1.704732
# 612       -0.482602        3.489006      3.006405   0.153374        0.153374
# 690       -6.119279        2.177896     -3.941383  -0.016857       -0.016857
# 695        0.166972        0.728616      0.895589   3.678099        3.678099
# 765       -2.411202       -2.506834     -4.918037  -1.437764       -1.437764
# 357      -22.375481        0.948361    -21.427120  -0.046078       -0.046078
# 0         -1.764278       -0.275741     -2.040019   0.409029        0.409029
#
#      war_playoffs  predator_offense  predator_defense  predator_total  \
# 805           0.0          1.802325         -0.483475        1.318850
# 718           0.0          5.933758         -0.304206        5.629552
# 47            0.0         -1.651205         -4.257850       -5.909055
# 624           0.0         -6.146549         -3.006482       -9.153031
# 80            0.0         -0.820220         -1.566644       -2.386864
# 143           0.0         -0.899255          0.415492       -0.483763
# 778           0.0         -3.176776         -4.485027       -7.661802
# 277           0.0          0.580532         -1.132491       -0.551960
# 99            0.0         -1.327603          0.426300       -0.901303
# 612           0.0         -0.650274          1.968116        1.317842
# 690           0.0         -3.771357         -0.675974       -4.447331
# 695           0.0          0.778393          1.463520        2.241912
# 765           0.0         -2.629093         -2.614859       -5.243952
# 357           0.0        -13.486166         -3.864807      -17.350973
# 0             0.0         -1.850761         -0.175280       -2.026041
#
#      pace_impact
# 805     1.049764
# 718    -0.060893
# 47     -0.133489
# 624     0.963404
# 80     -0.085262
# 143     0.120606
# 778    -0.154013
# 277    -0.326546
# 99     -0.928488
# 612     0.432139
# 690    -0.963128
# 695     1.057031
# 765     0.218829
# 357    -3.321351
# 0      -0.957109
#
# [15 rows x 23 columns]

# %%
raptordata.columns
# Out:
# Index(['player_name', 'player_id', 'season', 'season_type', 'team', 'poss',
#        'mp', 'raptor_box_offense', 'raptor_box_defense', 'raptor_box_total',
#        'raptor_onoff_offense', 'raptor_onoff_defense', 'raptor_onoff_total',
#        'raptor_offense', 'raptor_defense', 'raptor_total', 'war_total',
#        'war_reg_season', 'war_playoffs', 'predator_offense',
#        'predator_defense', 'predator_total', 'pace_impact'],
#       dtype='object')

# %%
dropcols = ['player_name', 'player_id', 'season_type', 'poss',
       'mp', 'raptor_box_offense', 'raptor_box_defense', 'raptor_box_total',
       'raptor_onoff_offense', 'raptor_onoff_defense', 'raptor_onoff_total',
       'raptor_offense', 'raptor_defense', 'war_total',
       'war_reg_season', 'war_playoffs', 'predator_offense',
       'predator_defense', 'predator_total', 'pace_impact']

# %%
# Drop unnecessary columns

virtualteamdf = virtualteamdf.drop(columns=dropcols)
virtualteamdf.head()
# Out:
#      season team  raptor_total
# 805    2023  NOP      3.581869
# 718    2023  BOS      3.703352
# 47     2023  WAS     -6.296874
# 624    2023  SAC     -9.713657
# 80     2023  LAC     -1.063059

# %%
# Ensure no missing/null values in the dataframe

display('NULL VALUES; ' , virtualteamdf.isnull().sum())
# Out:
# 'NULL VALUES; '
# season          0
# team            0
# raptor_total    0
# dtype: int64

# %%
# Group the dataframe by the 'season' column
# Calculate the total/sum of the team's raptor rating

groupsum = virtualteamdf.groupby(['season'], as_index=False).sum()
groupsum.head()
# Out:
#    season  raptor_total
# 0    2023    -47.125651

# %%
# Display NBA 2016-2023 season data

nbadf.head()
# Out:
#    season team  elo_rating  points   L   W     W%  conf  playoffs_y_n
# 0    2016  GSW      1800.0  9421.0   9  73  89.02  west             1
# 1    2016  SAS      1745.0  8490.0  15  67  81.71  west             1
# 2    2016  OKC      1630.0  9038.0  27  55  67.07  west             1
# 3    2016  LAC      1626.0  8569.0  29  53  64.63  west             1
# 4    2016  POR      1534.0  8622.0  38  44  53.66  west             1

# %%
# Create dataframe for the East Conference 2023 season
# Display statistical features of the numerical columns of the dataframe

nba2023 = nbadf.loc[(nbadf['season'] == 2023) & (nbadf['conf'] == 'east')]
nba2023.describe()
# Out:
#        season   elo_rating       points          L          W         W%  \
# count    15.0    15.000000    15.000000  15.000000  15.000000  15.000000
# mean   2023.0  1512.266667  9377.400000  40.466667  41.933333  50.890000
# std       0.0    83.362776   227.106583  11.224124  11.221578  13.677526
# min    2023.0  1346.000000  9045.000000  24.000000  17.000000  20.730000
# 25%    2023.0  1453.000000  9194.500000  33.000000  35.000000  42.680000
# 50%    2023.0  1527.000000  9359.000000  41.000000  42.000000  50.600000
# 75%    2023.0  1563.000000  9524.500000  47.000000  49.000000  59.760000
# max    2023.0  1653.000000  9827.000000  65.000000  58.000000  70.730000
#
#        playoffs_y_n
# count     15.000000
# mean       0.466667
# std        0.516398
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
# Generate random column values for virtual team using normal distribution
# Values used in the Numpy methods are gotten from the 'Mean' and 'Standard Deviation' of the respective columns in the NBA 2023 dataframe

points = np.random.normal(9377.400000, 227.106583, 1)
wins = np.random.normal(41.933333, 11.221578, 1)
losses = np.random.normal(40.466667, 11.224124, 1)
points, wins, losses
# Out:
# (array([8933.03315256]), array([37.54883873]), array([44.76679701]))

# %% [markdown]
# ## Virtual NBA 2023 Season
#
# * A virtual team of 15 randomly selected players was created and attached to the East Conference 2023 season.
# * The virtual team was assigned the name 'The Avengers' with alias; (TAV).
# * Random column values were generated to give the team a position in the 2023 league table.

# %%
# Generate column values

groupsum['team'] = 'TAV'
groupsum['points'] = points	
groupsum['L'] = losses
groupsum['W'] = wins
groupsum['W%'] = ((groupsum['W']/(groupsum['W'] + groupsum['L'])*100)).round(2)
groupsum['playoffs_y_n'] = np.nan
groupsum['conf'] = 'east'
groupsum.rename(columns={'raptor_total': 'elo_rating'}, inplace=True)

# %%
# Merge the virtual team dataframe with the 2023 season dataframe
# Sort the dataframe according to 'W%' to determine league positions

virtualnba2023 = pd.concat([nba2023, groupsum], axis=0, ignore_index=True)
virtualnba2023.sort_values('W%', ascending=False, ignore_index=True, inplace=True)
virtualnba2023
# Out:
#     season team   elo_rating       points          L          W     W%  conf  \
# 0     2023  MIL  1599.000000  9589.000000  24.000000  58.000000  70.73  east
# 1     2023  BOS  1653.000000  9671.000000  25.000000  57.000000  69.51  east
# 2     2023  PHI  1598.000000  9448.000000  28.000000  54.000000  65.85  east
# 3     2023  CLE  1577.000000  9205.000000  31.000000  51.000000  62.20  east
# 4     2023  NYK  1549.000000  9514.000000  35.000000  47.000000  57.32  east
# 5     2023  BRK  1541.000000  9295.000000  37.000000  45.000000  54.88  east
# 6     2023  MIA  1548.000000  9184.000000  39.000000  45.000000  53.57  east
# 7     2023  ATL  1518.000000  9827.000000  41.000000  42.000000  50.60  east
# 8     2023  TOR  1527.000000  9359.000000  42.000000  41.000000  49.40  east
# 9     2023  CHI  1493.000000  9476.000000  43.000000  41.000000  48.81  east
# 10    2023  TAV   -47.125651  8933.033153  44.766797  37.548839  45.62  east
# 11    2023  IND  1438.000000  9535.000000  47.000000  35.000000  42.68  east
# 12    2023  WAS  1468.000000  9279.000000  47.000000  35.000000  42.68  east
# 13    2023  ORL  1407.000000  9136.000000  48.000000  34.000000  41.46  east
# 14    2023  CHO  1422.000000  9098.000000  55.000000  27.000000  32.93  east
# 15    2023  DET  1346.000000  9045.000000  65.000000  17.000000  20.73  east
#
#     playoffs_y_n
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# 5            1.0
# 6            1.0
# 7            0.0
# 8            0.0
# 9            0.0
# 10           NaN
# 11           0.0
# 12           0.0
# 13           0.0
# 14           0.0
# 15           0.0

# %%
# Create function to dtermine which teams make it to playoffs

def playoffs(df):
    playoffslist = []
    for i in df.index.values.tolist():
        if i <= 6:
            playoffslist.append(1)
        else:
            playoffslist.append(0)
    df['playoffs_y_n'] = pd.Series(playoffslist)
    return df

# %%
# Determine teams that make it to playoffs

virtualnba2023 = playoffs(virtualnba2023)
virtualnba2023.head()
# Out:
#    season team  elo_rating  points     L     W     W%  conf  playoffs_y_n
# 0    2023  MIL      1599.0  9589.0  24.0  58.0  70.73  east             1
# 1    2023  BOS      1653.0  9671.0  25.0  57.0  69.51  east             1
# 2    2023  PHI      1598.0  9448.0  28.0  54.0  65.85  east             1
# 3    2023  CLE      1577.0  9205.0  31.0  51.0  62.20  east             1
# 4    2023  NYK      1549.0  9514.0  35.0  47.0  57.32  east             1

# %% [markdown]
# ## ML Predictions
#
# * Predict the teams that make it to 2023 playoffs using the already trained models.

# %%
# Load the trained models

logreg_model = joblib.load(r'C:\Users\User\Downloads\nba_data_science_project\models\conference_qualifiers_models\east_log_model.h5')
rfc_model = joblib.load(r'C:\Users\User\Downloads\nba_data_science_project\models\conference_qualifiers_models\east_rfc_model.h5')

# %%
# Select columns for normalizing

modeldata = virtualnba2023[['elo_rating', 'points', 'L', 'W', 'W%']]

# %%
# Normalize the dataframe

scaler = MinMaxScaler(feature_range=(0,1))
scaleddata = scaler.fit_transform(modeldata)
scaleddf = pd.DataFrame(scaleddata)

# %%
# Predict teams that make it to playoffs
# Predict the probabilities of each team making it to playoffs

predictions_2023 = virtualnba2023[["season", "team", "playoffs_y_n"]]

log_probability = logreg_model.predict_proba(scaleddf)[:,1].tolist()
rfc_probability = rfc_model.predict_proba(scaleddf)[:,1].tolist()

log_prediction = logreg_model.predict(scaleddf).tolist()
rfc_prediction = rfc_model.predict(scaleddf).tolist()

predictions_2023["prediction_log"] = log_prediction
predictions_2023["prob_log"] = log_probability
predictions_2023["prediction_rfc"] = rfc_prediction
predictions_2023["prob_rfc"] = rfc_probability

predictions_2023.sort_values("prob_log", ascending = False)
predictions_2023.sort_values("prob_rfc", ascending = False)
# Out:
#     season team  playoffs_y_n  prediction_log  prob_log  prediction_rfc  \
# 0     2023  MIL             1               1  0.953257               1
# 1     2023  BOS             1               1  0.948451               1
# 2     2023  PHI             1               1  0.911651               1
# 3     2023  CLE             1               1  0.855989               1
# 4     2023  NYK             1               1  0.760297               1
# 5     2023  BRK             1               1  0.686066               1
# 6     2023  MIA             1               1  0.645118               0
# 7     2023  ATL             0               1  0.568605               0
# 8     2023  TOR             0               1  0.510248               0
# 9     2023  CHI             0               0  0.487145               0
# 11    2023  IND             0               0  0.287400               0
# 12    2023  WAS             0               0  0.283834               0
# 13    2023  ORL             0               0  0.237346               0
# 14    2023  CHO             0               0  0.090398               0
# 15    2023  DET             0               0  0.017549               0
# 10    2023  TAV             0               0  0.128423               0
#
#     prob_rfc
# 0       1.00
# 1       1.00
# 2       1.00
# 3       1.00
# 4       1.00
# 5       0.78
# 6       0.24
# 7       0.18
# 8       0.05
# 9       0.05
# 11      0.04
# 12      0.04
# 13      0.04
# 14      0.04
# 15      0.04
# 10      0.00
